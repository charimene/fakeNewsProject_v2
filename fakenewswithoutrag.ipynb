# %%
# !pip install -q ddgs ollama
# !apt-get install -y zstd -qq
# !curl -fsSL https://ollama.com/install.sh | sh

# !pkill -f "ollama serve"
import time
time.sleep(2)

import subprocess, time

with open('/kaggle/working/ollama.log', 'w') as log_file:
    subprocess.Popen(['ollama', 'serve'], stdout=log_file, stderr=log_file)

time.sleep(5)
print("Service Ollama demarre")

# !ollama pull gemma3:4b
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 686.3 kB/s eta 0:00:000:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 20.2 MB/s eta 0:00:0000:0100:01
# Selecting previously unselected package zstd.
# (Reading database ... 125186 files and directories currently installed.)
# Preparing to unpack .../zstd_1.4.8+dfsg-3build1_amd64.deb ...
# Unpacking zstd (1.4.8+dfsg-3build1) ...
# Setting up zstd (1.4.8+dfsg-3build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# >>> Installing ollama to /usr/local
# >>> Downloading ollama-linux-amd64.tar.zst
# ######################################################################## 100.0%                                                  18.7%                           47.2%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.
# Service Ollama demarre
# ]11;?\pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling aeda25e63ebd:   1% ▕                  ▏  33 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   2% ▕                  ▏  70 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   5% ▕                  ▏ 156 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   8% ▕█                 ▏ 250 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:   9% ▕█                 ▏ 293 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  11% ▕██                ▏ 379 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  14% ▕██                ▏ 456 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  15% ▕██                ▏ 499 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  17% ▕███               ▏ 573 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  19% ▕███               ▏ 641 MB/3.3 GB                  pulling manifest
# pulling aeda25e63ebd:  20% ▕███               ▏ 672 MB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  22% ▕███               ▏ 740 MB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  24% ▕████              ▏ 806 MB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  25% ▕████              ▏ 848 MB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  28% ▕████              ▏ 922 MB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  29% ▕█████             ▏ 983 MB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  30% ▕█████             ▏ 1.0 GB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  32% ▕█████             ▏ 1.1 GB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  34% ▕██████            ▏ 1.1 GB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  35% ▕██████            ▏ 1.2 GB/3.3 GB  670 MB/s      3spulling manifest
# pulling aeda25e63ebd:  36% ▕██████            ▏ 1.2 GB/3.3 GB  602 MB/s      3spulling manifest
# pulling aeda25e63ebd:  38% ▕██████            ▏ 1.3 GB/3.3 GB  602 MB/s      3spulling manifest
# pulling aeda25e63ebd:  39% ▕███████           ▏ 1.3 GB/3.3 GB  602 MB/s      3spulling manifest
# pulling aeda25e63ebd:  41% ▕███████           ▏ 1.4 GB/3.3 GB  602 MB/s      3spulling manifest
# pulling aeda25e63ebd:  43% ▕███████           ▏ 1.4 GB/3.3 GB  602 MB/s      3spulling manifest
# pulling aeda25e63ebd:  44% ▕███████           ▏ 1.5 GB/3.3 GB  602 MB/s      3spulling manifest
# pulling aeda25e63ebd:  45% ▕████████          ▏ 1.5 GB/3.3 GB  602 MB/s      3spulling manifest
# pulling aeda25e63ebd:  46% ▕████████          ▏ 1.5 GB/3.3 GB  602 MB/s      2spulling manifest
# pulling aeda25e63ebd:  47% ▕████████          ▏ 1.6 GB/3.3 GB  602 MB/s      2spulling manifest
# pulling aeda25e63ebd:  48% ▕████████          ▏ 1.6 GB/3.3 GB  602 MB/s      2spulling manifest
# pulling aeda25e63ebd:  49% ▕████████          ▏ 1.6 GB/3.3 GB  541 MB/s      3spulling manifest
# pulling aeda25e63ebd:  49% ▕████████          ▏ 1.6 GB/3.3 GB  541 MB/s      3spulling manifest
# pulling aeda25e63ebd:  51% ▕█████████         ▏ 1.7 GB/3.3 GB  541 MB/s      3spulling manifest
# pulling aeda25e63ebd:  52% ▕█████████         ▏ 1.7 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  53% ▕█████████         ▏ 1.8 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  54% ▕█████████         ▏ 1.8 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  56% ▕██████████        ▏ 1.9 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  57% ▕██████████        ▏ 1.9 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  58% ▕██████████        ▏ 2.0 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  60% ▕██████████        ▏ 2.0 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  61% ▕███████████       ▏ 2.1 GB/3.3 GB  541 MB/s      2spulling manifest
# pulling aeda25e63ebd:  63% ▕███████████       ▏ 2.1 GB/3.3 GB  519 MB/s      2spulling manifest
# pulling aeda25e63ebd:  65% ▕███████████       ▏ 2.2 GB/3.3 GB  519 MB/s      2spulling manifest
# pulling aeda25e63ebd:  66% ▕███████████       ▏ 2.2 GB/3.3 GB  519 MB/s      2spulling manifest
# pulling aeda25e63ebd:  68% ▕████████████      ▏ 2.3 GB/3.3 GB  519 MB/s      2spulling manifest
# pulling aeda25e63ebd:  70% ▕████████████      ▏ 2.3 GB/3.3 GB  519 MB/s      1spulling manifest
# pulling aeda25e63ebd:  71% ▕████████████      ▏ 2.4 GB/3.3 GB  519 MB/s      1spulling manifest
# pulling aeda25e63ebd:  73% ▕█████████████     ▏ 2.4 GB/3.3 GB  519 MB/s      1spulling manifest
# pulling aeda25e63ebd:  75% ▕█████████████     ▏ 2.5 GB/3.3 GB  519 MB/s      1spulling manifest
# pulling aeda25e63ebd:  76% ▕█████████████     ▏ 2.5 GB/3.3 GB  519 MB/s      1spulling manifest
# pulling aeda25e63ebd:  77% ▕█████████████     ▏ 2.6 GB/3.3 GB  519 MB/s      1spulling manifest
# pulling aeda25e63ebd:  79% ▕██████████████    ▏ 2.6 GB/3.3 GB  520 MB/s      1spulling manifest
# pulling aeda25e63ebd:  79% ▕██████████████    ▏ 2.6 GB/3.3 GB  520 MB/s      1spulling manifest
# pulling aeda25e63ebd:  81% ▕██████████████    ▏ 2.7 GB/3.3 GB  520 MB/s      1spulling manifest
# pulling aeda25e63ebd:  82% ▕██████████████    ▏ 2.8 GB/3.3 GB  520 MB/s      1spulling manifest
# pulling aeda25e63ebd:  83% ▕███████████████   ▏ 2.8 GB/3.3 GB  520 MB/s      1spulling manifest
# pulling aeda25e63ebd:  85% ▕███████████████   ▏ 2.8 GB/3.3 GB  520 MB/s      0spulling manifest
# pulling aeda25e63ebd:  87% ▕███████████████   ▏ 2.9 GB/3.3 GB  520 MB/s      0spulling manifest
# pulling aeda25e63ebd:  88% ▕███████████████   ▏ 2.9 GB/3.3 GB  520 MB/s      0spulling manifest
# pulling aeda25e63ebd:  90% ▕████████████████  ▏ 3.0 GB/3.3 GB  520 MB/s      0spulling manifest
# pulling aeda25e63ebd:  92% ▕████████████████  ▏ 3.1 GB/3.3 GB  520 MB/s      0spulling manifest
# pulling aeda25e63ebd:  92% ▕████████████████  ▏ 3.1 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  93% ▕████████████████  ▏ 3.1 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  95% ▕█████████████████ ▏ 3.2 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  96% ▕█████████████████ ▏ 3.2 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  96% ▕█████████████████ ▏ 3.2 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  97% ▕█████████████████ ▏ 3.2 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  97% ▕█████████████████ ▏ 3.2 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  98% ▕█████████████████ ▏ 3.3 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  98% ▕█████████████████ ▏ 3.3 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  98% ▕█████████████████ ▏ 3.3 GB/3.3 GB  513 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  469 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd:  99% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕█████████████████ ▏ 3.3 GB/3.3 GB  414 MB/s      0spulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB                         pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠦ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠧ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠇ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠏ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠋ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠙ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠹ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠸ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠼ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest ⠴ pulling manifest
# pulling aeda25e63ebd: 100% ▕██████████████████▏ 3.3 GB
# verifying sha256 digest
# writing manifest
# success

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

import csv
import random
import re
import time
import ollama
from ddgs import DDGS
from collections import Counter

# %% [markdown]
# **TESTER MA CONFIG**
#
# **DEBUT**

# %%
# !nvidia-smi
# Out:
# Thu Sep 24 01:08:46 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8             15W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !ollama run gemma3:4b "Dis bonjour en une phrase"
# Out:
# ]11;?\⠙ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠏ ⠋ ⠙ ⠹ ⠹ ⠸ ⠴ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠸ ⠴ ⠦ ⠦ ⠇ ⠏ ⠋ ⠙ ⠙ ⠸ ⠼ ⠼ ⠴ ⠦ ⠇ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠏ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠴ ⠦ ⠇ ⠏ ⠋ ⠙ ⠙ ⠹ ⠸ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠙ ⠹ ⠸ ⠼ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠇ ⠋ ⠙ ⠙ ⠹ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠋ ⠙ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠇ ⠏ ⠏ ⠋ ⠙ ⠸ ⠼ ⠼ ⠦ ⠧ ⠧ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠴ ⠦ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠏ ⠏ ⠙ ⠙ ⠹ ⠼ ⠴ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠸ ⠼ ⠴ ⠴ ⠦ ⠧ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠸ ⠼ ⠴ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠸ ⠸ ⠴ ⠦ ⠧ ⠇ ⠏ ⠏ ⠋ ⠙ ⠹ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠙ ⠹ ⠹ ⠸ ⠼ ⠴ ⠧ ⠧ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠹ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠇ ⠋ ⠋ ⠹ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠙ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠸ ⠸ ⠼ ⠴ ⠦ ⠇ ⠏ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠴ ⠧ ⠇ ⠏ ⠏ ⠋ ⠹ ⠸ ⠸ ⠼ ⠴ ⠧ ⠧ ⠏ ⠋ ⠙ ⠙ ⠸ ⠼ ⠼ ⠴ ⠧ ⠧ ⠇ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠴ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠏ ⠋ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠙ ⠙ ⠹ ⠸ ⠼ ⠦ ⠧ ⠧ ⠇ ⠏ ⠙ ⠹ ⠹ ⠸ ⠼ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠇ ⠏ ⠙ ⠹ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠸ ⠸ ⠼ ⠦ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠸ ⠼ ⠦ ⠧ ⠇ ⠇ ⠏ ⠙ ⠹ ⠹ ⠸ ⠴ ⠦ ⠦ ⠇ ⠏ ⠏ ⠋ ⠙ ⠸ ⠸ ⠼ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠹ ⠹ ⠸ ⠴ ⠦ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠇ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠋ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠇ ⠇ ⠋ ⠙ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠇ ⠏ ⠙ ⠹ ⠸ ⠼ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠸ ⠼ ⠴ ⠦ ⠦ ⠧ ⠏ ⠏ ⠋ ⠙ ⠸ ⠼ ⠼ ⠦ ⠦ ⠧ ⠏ ⠋ ⠋ ⠙ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠏ ⠏ ⠋ ⠹ ⠸ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠧ ⠧ ⠇ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠋ ⠹ ⠸ ⠸ ⠴ ⠦ ⠦ ⠧ ⠇ ⠋ ⠙ ⠙ ⠹ ⠸ ⠴ ⠴ ⠦ ⠧ ⠇ ⠋ ⠙ ⠹ ⠹ ⠼ ⠼ ⠴ ⠦ ⠇ ⠇ ⠏ ⠋ ⠹ ⠹ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠹ ⠼ ⠴ ⠦ ⠧ ⠧ ⠇ ⠏ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠏ ⠋ ⠙ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠇ ⠇ ⠏ ⠋ ⠹ ⠸ ⠼ ⠼ ⠴ ⠧ ⠧ ⠇ ⠏ ⠋ ⠹ ⠸ ⠸ ⠼ ⠴ ⠧ ⠧ ⠏ ⠏ ⠋ ⠙ ⠹ ⠼ ⠼ ⠦ ⠧ ⠇ ⠏ ⠏ ⠙ ⠙ ⠹ ⠼ ⠴ ⠴ ⠦ ⠇ ⠇ ⠋ ⠋ ⠙ ⠸ ⠸ ⠴ ⠦ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠸ ⠼ ⠴ ⠧ ⠇ ⠇ ⠏ ⠋ ⠙ ⠹ ⠸ ⠴ ⠴ ⠦ ⠧ ⠏ ⠋ ⠙ ⠙ ⠸ ⠼ ⠴ ⠦ ⠧ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠙ ⠹ ⠼ ⠴ ⠴ ⠧ ⠧ ⠇ ⠏ ⠙ ⠹ ⠹ ⠼ ⠴ ⠴ ⠦ ⠧ ⠇ ⠏ ⠙ ⠹ ⠸ ⠼ ⠼ ⠴ ⠦ ⠧ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠴ ⠦ ⠧ ⠏ ⠋ ⠋ ⠹ ⠹ ⠼ ⠴ ⠦ ⠦ ⠧ ⠇ ⠋ ⠋ ⠙ ⠹ ⠸ ⠼ ⠦ ⠦ ⠧ ⠇ Bien sûr ! Voici une phrase pour dire bonjour :
#
# "Bonjour à tous !"

# %%
# !ollama run gemma3:4b "Dis bonjour autrement"
# Out:
# ]11;?\Il existe de nombreuses façons de dire "bonjour" autrement, en fonction du
# contexte et de la personne à qui vous vous adressez ! Voici quelques sugges
# suggestions :
#
# **Formel:**
#
# *   **Bonjour Madame/Monsieur :** La formule la plus courante pour une salu
# salutation formelle.
# *   **Salutations :** Plus soutenu et utilisé dans des contextes très forme
# formels.
#
# **Informel:**
#
# *   **Salut :** Le plus courant et décontracté.
# *   **Coucou :** Très affectueux, souvent utilisé entre amis proches ou en
# famille.
# *   **Yo :** (Plus jeune) Très informel et décontracté, à utiliser avec pru
# prudence.
# *   **Allô :**  Souvent utilisé lorsqu'on décroche le téléphone, mais peut
# aussi être employé de manière informelle.
# *   **Bien le bonjour :** Un peu vieillot mais charmant.
#
# **Selon l'heure de la journée:**
#
# *   **Bonne matinée :**  Utilisé avant midi.
# *   **Bonne après-midi :** Utilisé entre midi et 18h.
# *   **Bonne soirée :** Utilisé après 18h.
#
# **Autres options :**
#
# *   **Bienvenue :** Pour accueillir quelqu'un.
# *   **Enchanté(e) :** (si vous rencontrez quelqu'un pour la première fois)
# *   **Ça va ? / Comment allez-vous ?** (Si vous voulez prendre plus de temp
# temps pour la conversation)
#
# **Pour choisir la meilleure alternative, pensez à:**
#
# *   **L'âge de la personne à qui vous vous adressez.**
# *   **La relation que vous avez avec cette personne.**
# *   **Le contexte de la situation.**
#
# N'hésitez pas à me dire quel type de situation vous avez en tête, et je pou
# pourrai vous donner une suggestion plus précise !  Par exemple, cherchez-vo
# cherchez-vous une formule pour une carte de vœux, pour un e-mail, ou pour u
# une conversation avec un ami ?

# %%
reponse = ollama.chat(model="gemma3:4b", messages=[
    {"role": "user", "content": "Dis bonjour en une phrase"}
])
print(reponse["message"]["content"])
# Out:
# Bien sûr ! Voici une phrase pour dire bonjour :
#
# "Bonjour à tous !"

# %%
resultats = DDGS().text("Miley Cyrus Liam Hemsworth married", max_results=3)
for r in resultats:
    print(r["title"], "-", r["href"])
# Out:
# Miley Cyrus and Liam Hemsworth's Relationship Timeline - https://people.com/music/miley-cyrus-liam-hemsworth-engagement-relationship-in-photos/
# Miley Cyrus Shares Moment She Realized Liam Hemsworth ... - HuffPost - https://www.huffpost.com/entry/miley-cyrus-liam-hemsworth-divorce_n_64f8af65e4b0e9b3e9e9835d
# See All of Miley Cyrus and Liam Hemsworth's Wedding Photos - https://people.com/style/miley-cyrus-liam-hemsworth-wedding-photos/

# %% [markdown]
# **FIN DES TESTS**

# %%
taille = 150
m = "gemma3:4b"
var_aleatoire = 30

random.seed(var_aleatoire)

def lire_csv(chemin):
    with open(chemin, newline="", encoding="utf-8") as f:
        return list(csv.DictReader(f))

# fonction qui va retourner n articles du fichier csv lignes
def echantillonner(lignes, n):
    n = min(n, len(lignes))
    return random.sample(lignes, n)

# %%
def chercher_preuves(titre, texte):
    # cherche sur web des infos sur le texte passé en param
    # retourne les 3 premiers resultats trouvés formatés en liste de points

    requete = titre if titre else texte[:100]
    try:
        resultats = DDGS().text(requete, max_results=3)
    except Exception as e:
        print(f"  Erreur de recherche : {e}")
        return "(aucune preuve trouvee)"

    if not resultats:
        return "(aucune preuve trouvee)"

    morceaux = []
    for r in resultats:
        morceaux.append(f"- {r.get('title', '')} : {r.get('body', '')[:200]}")
    return "\n".join(morceaux)

# %%
def chercher_preuves_2(titre, texte, max_tentatives=3):
    # cherche sur web des infos sur le texte passé en param
    # retourne les 3 premiers resultats trouvés formatés en liste de points
    # difference avec l'autre, si on échoue a trouver des preuves, on essaye jusqu'a 3 tentatives

    requete = titre if titre else texte[:100]

    for tentative in range(1, max_tentatives + 1):
        try:
            # timeout augmente a 20s (au lieu de 5s par defaut)
            with DDGS(timeout=20) as ddgs:
                resultats = ddgs.text(query=requete, max_results=3)

            if not resultats:
                return "(aucune preuve trouvee)"

            morceaux = []
            for r in resultats:
                morceaux.append(f"- {r.get('title', '')} : {r.get('body', '')[:200]}")
            return "\n".join(morceaux)

        except Exception as e:
            print(f"  [!] Tentative {tentative}/{max_tentatives} echouee : {e}")
            if tentative < max_tentatives:
                # attend de plus en plus longtemps a chaque tentative (3s, 6s, 9s)
                time.sleep(3 * tentative)

    # si toutes les tentatives ont echoue
    return "(aucune preuve trouvee apres plusieurs tentatives)"

# %%
def construire_prompt(titre, texte, source):
    texte_court = texte[:800]

    prompt = "Voici un article a verifier.\n\n"
    prompt = prompt + "Source : " + source + "\n"
    prompt = prompt + "Titre : " + titre + "\n"
    prompt = prompt + "Texte : " + texte_court + "\n\n"
    prompt = prompt + "Preuves trouvees sur le web concernant cette affirmation :\n\n"
    prompt = prompt + "En te basant sur ce que tu connais, verifie si l'affirmation de cet article est vraie ou fausse.\n"
    prompt = prompt + "Reponds uniquement par un seul mot : \"fake\" ou \"real\"."

    return prompt


def extraire_verdict(reponse_llm):
    texte = reponse_llm.lower()
    if re.search(r"\bfake\b", texte):
        return "fake"
    if re.search(r"\breal\b", texte):
        return "real"
    return "indetermine"


def extraire_verdict_2(reponse_llm):
    texte = reponse_llm.lower().strip()
    # Si la reponse est longue, c'est surement pas un real ou un fake 
    if len(texte.split()) > 5:
        return "indetermine"
    if re.search(r"\bfake\b", texte):
        return "fake"
    if re.search(r"\breal\b", texte):
        return "real"
    return "indetermine"

# %%
def demander_verdict(titre, texte, source):

    prompt = construire_prompt(titre, texte, source)

    reponse = ollama.chat(model=m, messages=[{"role": "user", "content": prompt}])

    contenu = reponse["message"]["content"]

    return extraire_verdict(contenu)

# %% [markdown]
# **TEST**

# %%
# On charge le fichier B et on prend juste le premier article pour tester
lignes_test = lire_csv("/kaggle/input/datasets/imenec/data-in/categorie_B_egalise.csv")
article_test = lignes_test[0]

titre = article_test.get("title", "")
texte = article_test.get("text", "")
source = article_test.get("domaine", "source inconnue")
vrai_label = article_test.get("label", "")

print("Titre :", titre)
print("Source :", source)
print("Vrai label :", vrai_label)

verdict = demander_verdict(titre, texte, source)
print("\nVerdict du LLM :", verdict)
# Out:
# Titre : Apology To Sarah Ferguson
# Source : radaronline.com
# Vrai label : fake
#
# Preuves trouvees :
#  - Sarah Ferguson Sends Cards With 'Gushing Apology’ To Royals | Gallery | Wonderwall.com : December 23, 2025 - Sarah Ferguson reportedly issued a 'gushing apology' to the royal family in her solo holiday cards after being stripped of her title.
# - Sarah Ferguson has been issued an apology after false claims surfaced of a 'tell-all' book on the royals : August 22, 2019 - However, the publication has now issued an apology to Sarah after admitting it was based on “pure speculation”. ... Posted @withrepost • @antoniamarshall @sarahferguson15 was just is
# - Sarah Ferguson Has Quietly Reached Out to The Royals With Emotional Apology Cards - The Royal Observer : December 18, 2025 - While King Charles rescued his brother, offering him his estate in Sandringham, Ferguson was left to fend for herself, and now she has decided to surrender the battle. There is no
#
# Verdict du LLM : real

# %% [markdown]
# **FIN de TEST**

# %%
# a revoir
def test_groupe(chemin_csv, nom_groupe, chemin_sortie, taille_groupe):
    print(f"\n Traitement du groupe {nom_groupe} :")

    lignes = lire_csv(chemin_csv)
    #echantillonner est un moyen pour tester sur un groupe restreint d'Article au lieu du groupe au complet
    echantillon = echantillonner(lignes, taille_groupe)

    print(f"{len(echantillon)} articles a traiter")

    colonnes_resultat = ["id", "domaine", "vrai_label", "verdict_llm", "correct"]
    resultats = []

    with open(chemin_sortie, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=colonnes_resultat)
        writer.writeheader()

        for i, article in enumerate(echantillon):
            titre = article.get("title", "")
            texte = article.get("text", "")
            source = article.get("domaine", "source inconnue")
            vrai_label = article.get("label", "")

           
            time.sleep(1)

            verdict = demander_verdict(titre, texte, source)
            correct = "oui" if verdict == vrai_label else "non"

            ligne_resultat = {
                "id": article.get("id", ""),
                "domaine": source,
                "vrai_label": vrai_label,
                "verdict_llm": verdict,
                "correct": correct,
            }
            writer.writerow(ligne_resultat)
            resultats.append(ligne_resultat)

            print(f"  [{i + 1}/{len(echantillon)}] {source} -> vrai={vrai_label}, LLM={verdict}, correct={correct}")

    return resultats

# %% [markdown]
# **Expérience 1 :**
#
# on va interroger le LLM 3 fois une fois en mentionnant la vraie source originale du Média, la 2e fois en changeant la source, et la 3e fois sans mentionner la source.

# %%
def verdict_n_fois(titre, texte, source, n=5):
    # Fonction qui appelle le LLM n fois avec les memes parametres
    # et renvoie le verdict 
    # on lance n fois pour chercher une certaine stabilité dans les reponses du modele
    # apres je prends la verdict majoritaire retourné

    verdicts = []
    for i in range(n):
        v = demander_verdict(titre, texte, source)
        verdicts.append(v)
        
    # compte combien a chaque fois cahque valeur apparait dans la liste
    compte = Counter(verdicts)
    # retourne l'element le plus frequent, [0][0] pour chercher l'etiquette real ou fake
    majorite = compte.most_common(1)[0][0]
    return majorite, verdicts

# %%
def tester_contrefactuel(article, source_2 ,pas_source="source non identifiée"):
    
    # exemple de source peu connue : yournewswire.com
    # exemple de source connue : dailymail.co.uk
    # Je teste un article 3 fois : 
    # une fois avec sa vraie source originale,
    # une fois avec une source oposée au statut de la source originale
    # si la source originale est connue, on changera pour une source peu_connue et virce versa
    # une fois en anonymisant la source en mettant a la place "source non identifiée"
    # mais en gardant -- meme contenu, meme preuves.
    
    titre = article.get("title", "")
    texte = article.get("text", "")
    vraie_source = article.get("domaine", "source inconnue")
    vrai_label = article.get("label", "")

    # Version 1 : avec la vraie source 
    verdict_original, n_original = verdict_n_fois(titre, texte, vraie_source)

    # Version 2 : source changée pour l'opposé de la source originale
    verdict_oppose, n_oppose = verdict_n_fois(titre, texte, source_2)

    # Version 3 : source rendue anonyme
    verdict_anonyme, n_anonyme = verdict_n_fois(titre, texte, pas_source)
    

    # flip = oui sil y a au moins un verdict different entre les 3 rendus
    if verdict_original == verdict_oppose == verdict_anonyme:
        flip = "non"
    else:
        flip = "oui"

    return {
        "id": article.get("id", ""),
        "vraie_source": vraie_source,
        "vrai_label": vrai_label,
        "verdict_original": verdict_original,
        "verdict_oppose": verdict_oppose,
        "verdict_anonyme": verdict_anonyme,
        "flip": flip,
    }

# %%
def lancer_test_contrefactuel(chemin_csv, taille_echantillon, chemin_sortie, source_2):
    lignes = lire_csv(chemin_csv)
    echantillon = echantillonner(lignes, taille_echantillon)

    colonnes = ["id", "vraie_source", "vrai_label", "verdict_original", "verdict_oppose" ,"verdict_anonyme", "flip"]
    resultats = []

    with open(chemin_sortie, "w", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(f, fieldnames=colonnes)
        writer.writeheader()

        for i, article in enumerate(echantillon):
            r = tester_contrefactuel(article,source_2)
            writer.writerow(r)
            resultats.append(r)
            print(f"[{i+1}/{len(echantillon)}] {r['vraie_source']} -> vraiLabel={r['vrai_label']}, original={r['verdict_original']}, oppose={r['verdict_oppose']} ,anonyme={r['verdict_anonyme']}, flip={r['flip']}")
            
    return resultats

# %%
chemin_in = "/kaggle/input/datasets/imenec/data-in/"
chemin_out = "/kaggle/working/"

resultats_contrefactuel = lancer_test_contrefactuel(
    chemin_csv=chemin_in + "categorie_B_egalise.csv",
    taille_echantillon=150,
    chemin_sortie=chemin_out + "resultats_contrefactuel_B_WRAG.csv",
    source_2="yournewswire.com"
)
# Out:
# [1/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [2/150] pinterest.co.uk -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [3/150] revolt.tv -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [4/150] ibtimes.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [5/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [6/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [7/150] breitbart.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [8/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [9/150] self.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [10/150] thesun.co.uk -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [11/150] cmt.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [12/150] hollywoodlife.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [13/150] independent.ie -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [14/150] ranker.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [15/150] eonline.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=fake, flip=oui
# [16/150] thehollywoodgossip.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [17/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [18/150] yourtango.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [19/150] billboard.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [20/150] usmagazine.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [21/150] news.com.au -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [22/150] intouchweekly.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [23/150] hollywoodlife.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=fake, flip=oui
# [24/150] denofgeek.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [25/150] cosmopolitan.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [26/150] amc.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [27/150] dailymail.co.uk -> vraiLabel=fake, original=real, oppose=fake ,anonyme=real, flip=oui
# [28/150] meaww.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [29/150] narcity.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=real, flip=oui
# [30/150] brit.co -> vraiLabel=real, original=real, oppose=fake ,anonyme=real, flip=oui
# [31/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [32/150] tmz.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [33/150] biography.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [34/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [35/150] usmagazine.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=fake, flip=oui
# [36/150] sheknows.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [37/150] senate.gov -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [38/150] mid-day.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [39/150] cosmopolitan.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [40/150] medium.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [41/150] popculture.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [42/150] popculture.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [43/150] capitalfm.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [44/150] elitedaily.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [45/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [46/150] today.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [47/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [48/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [49/150] ibtimes.co.uk -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [50/150] sheknows.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [51/150] teenvogue.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [52/150] billboard.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [53/150] vibe.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [54/150] amazon.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=real, flip=oui
# [55/150] medium.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=real, flip=oui
# [56/150] brides.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [57/150] today.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [58/150] lorealparisusa.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [59/150] lifeandstylemag.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [60/150] okmagazine.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=real, flip=oui
# [61/150] mashable.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [62/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [63/150] cosmopolitan.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [64/150] tvline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [65/150] eonline.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=fake, flip=oui
# [66/150] pagesix.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [67/150] pagesix.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [68/150] icel.edu.mx -> vraiLabel=fake, original=real, oppose=fake ,anonyme=real, flip=oui
# [69/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [70/150] refinery29.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [71/150] eonline.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [72/150] perezhilton.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=real, flip=oui
# [73/150] hollywoodlife.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [74/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [75/150] townandcountrymag.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=fake, flip=oui
# [76/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [77/150] okmagazine.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [78/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [79/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [80/150] newslocker.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [81/150] mid-day.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [82/150] bravotv.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [83/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [84/150] cosmopolitan.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [85/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [86/150] hollywoodlife.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=real, flip=oui
# [87/150] movieweb.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [88/150] aceshowbiz.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [89/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [90/150] radaronline.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [91/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [92/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [93/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [94/150] refinery29.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [95/150] youtube.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [96/150] bravotv.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [97/150] instyle.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [98/150] hollywoodlife.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [99/150] imdb.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [100/150] hollywoodlife.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=fake, flip=oui
# [101/150] hindustantimes.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [102/150] etonline.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [103/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [104/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [105/150] standard.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [106/150] elitedaily.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [107/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [108/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [109/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [110/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [111/150] efe.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [112/150] theblast.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [113/150] instagram.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [114/150] iheartradio.ca -> vraiLabel=real, original=real, oppose=fake ,anonyme=real, flip=oui
# [115/150] capitalfm.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [116/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [117/150] medium.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [118/150] dailymail.co.uk -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [119/150] today.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [120/150] medium.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [121/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [122/150] hollywoodlife.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=real, flip=oui
# [123/150] teamusa.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [124/150] news.com.au -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [125/150] metro.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [126/150] hollywoodlife.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=real, flip=oui
# [127/150] okmagazine.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [128/150] refinery29.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=fake, flip=oui
# [129/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [130/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [131/150] refinery29.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=fake, flip=oui
# [132/150] amazon.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [133/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [134/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [135/150] iheartradio.ca -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [136/150] etonline.com -> vraiLabel=real, original=real, oppose=fake ,anonyme=real, flip=oui
# [137/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=fake ,anonyme=fake, flip=oui
# [138/150] popculture.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [139/150] hercampus.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [140/150] dailymail.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [141/150] elitedaily.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [142/150] inquisitr.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [143/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [144/150] okmagazine.com -> vraiLabel=fake, original=real, oppose=fake ,anonyme=fake, flip=oui
# [145/150] cheatsheet.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [146/150] usmagazine.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [147/150] etonline.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [148/150] hollywoodlife.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [149/150] cosmopolitan.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [150/150] popsugar.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non

# %%
chemin_in = "/kaggle/input/datasets/imenec/data-in/"
chemin_out = "/kaggle/working/"

resultats_contrefactuel = lancer_test_contrefactuel(
    chemin_csv=chemin_in + "categorie_D_egalise.csv",
    taille_echantillon=150,
    chemin_sortie=chemin_out + "resultats_contrefactuel_D_WRAG.csv",
    source_2="dailymail.co.uk"
)
# Out:
# [1/150] wstale.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [2/150] wonderwall.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [3/150] k92radio.com -> vraiLabel=real, original=indetermine, oppose=indetermine ,anonyme=indetermine, flip=non
# [4/150] scoopnest.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [5/150] allabouttrh.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [6/150] trueara.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [7/150] biphoo.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [8/150] timesofindia.indiatimes.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [9/150] cupidspulse.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [10/150] thomas.loc.gov -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [11/150] rarolae.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [12/150] 1043myfm.iheart.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [13/150] newidea.com.au -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [14/150] corporate.wwe.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [15/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [16/150] ohnotheydidnt.livejournal.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [17/150] ebru.co.ke -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [18/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [19/150] w3.nexis.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [20/150] thequiz.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [21/150] onenewspage.us -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [22/150] wopular.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [23/150] thatgrapejuice.net -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [24/150] enstarz.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [25/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=fake ,anonyme=indetermine, flip=oui
# [26/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=indetermine ,anonyme=indetermine, flip=non
# [27/150] greysanatomy.fandom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [28/150] biphoo.com -> vraiLabel=real, original=fake, oppose=real ,anonyme=fake, flip=oui
# [29/150] getuperica.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [30/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [31/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=indetermine ,anonyme=indetermine, flip=non
# [32/150] celebrityinsider.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [33/150] anastasiabeverlyhills.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [34/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [35/150] transcripts.cnn.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [36/150] tv.avclub.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [37/150] newidea.com.au -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [38/150] longroom.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [39/150] msnbc.msn.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [40/150] nowtolove.com.au -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [41/150] nationalenquirer.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [42/150] cvikas.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [43/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=indetermine ,anonyme=indetermine, flip=non
# [44/150] youth-junction.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [45/150] journalpost.com -> vraiLabel=fake, original=fake, oppose=real ,anonyme=fake, flip=oui
# [46/150] kardashiantoday.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [47/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [48/150] gossipbucket.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [49/150] handphone-blackmarket.tk -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=indetermine, flip=oui
# [50/150] cq.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [51/150] instylemag.com.au -> vraiLabel=fake, original=real, oppose=real ,anonyme=fake, flip=oui
# [52/150] clip.fail -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [53/150] bojtv.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [54/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=indetermine ,anonyme=indetermine, flip=non
# [55/150] news.iheart.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [56/150] hugtdy.co -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [57/150] kartiavelino.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [58/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [59/150] whimn.com.au -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [60/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=indetermine ,anonyme=indetermine, flip=non
# [61/150] dailynews.news -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [62/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [63/150] newidea.com.au -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [64/150] en.wikipedia.org -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [65/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [66/150] thetechsensei.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [67/150] w3livenews.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [68/150] her.ie -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [69/150] us.blastingnews.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=fake, flip=oui
# [70/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=fake ,anonyme=indetermine, flip=oui
# [71/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=indetermine ,anonyme=fake, flip=oui
# [72/150] womenandhollywood.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [73/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [74/150] inconnu -> vraiLabel=fake, original=indetermine, oppose=fake ,anonyme=indetermine, flip=oui
# [75/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [76/150] directexpose.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [77/150] longroom.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [78/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [79/150] stayglam.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [80/150] 951wayv.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [81/150] news9ontime.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [82/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [83/150] caras.com.mx -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [84/150] en.paperblog.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [85/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [86/150] longroom.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [87/150] litefm.iheart.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [88/150] enstarz.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [89/150] shefinds.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [90/150] oceandraw.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [91/150] teddystick.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [92/150] celebitchy.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=fake, flip=oui
# [93/150] etcanada.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [94/150] redcarpet-fashionawards.com -> vraiLabel=real, original=real, oppose=real ,anonyme=fake, flip=oui
# [95/150] celebrityinsider.org -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [96/150] frostsnow.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [97/150] ftw.usatoday.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [98/150] abc.go.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [99/150] celebretainment.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [100/150] usadailypost.us -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [101/150] select.nytimes.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [102/150] 15minutenews.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [103/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [104/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [105/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [106/150] nextdivas.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [107/150] scoopnest.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [108/150] trueara.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [109/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [110/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [111/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [112/150] marquee.blogs.cnn.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [113/150] inconnu -> vraiLabel=real, original=indetermine, oppose=fake ,anonyme=indetermine, flip=oui
# [114/150] article.wn.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [115/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [116/150] newidea.com.au -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [117/150] metdaan.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [118/150] hot963.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=fake, flip=oui
# [119/150] newidea.com.au -> vraiLabel=fake, original=real, oppose=real ,anonyme=fake, flip=oui
# [120/150] web-site-design.info -> vraiLabel=fake, original=fake, oppose=real ,anonyme=fake, flip=oui
# [121/150] tech2.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [122/150] bojtv.com -> vraiLabel=real, original=real, oppose=real ,anonyme=fake, flip=oui
# [123/150] allmyfriendsaremodels.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [124/150] whimn.com.au -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [125/150] buzznews.co.uk -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [126/150] lastminutestuff.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [127/150] celebritymaximum.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [128/150] soundbooks.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [129/150] pennews.pencidesign.com -> vraiLabel=real, original=fake, oppose=real ,anonyme=fake, flip=oui
# [130/150] inconnu -> vraiLabel=real, original=indetermine, oppose=indetermine ,anonyme=indetermine, flip=non
# [131/150] article.wn.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [132/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=fake, flip=oui
# [133/150] 9jaikeji.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [134/150] trueara.com -> vraiLabel=real, original=fake, oppose=fake ,anonyme=fake, flip=non
# [135/150] x17online.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [136/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [137/150] gossipbucket.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [138/150] thejasminebrand.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=real, flip=non
# [139/150] newsdeskpress.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [140/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [141/150] soundbooks.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [142/150] docshop.com -> vraiLabel=fake, original=real, oppose=real ,anonyme=fake, flip=oui
# [143/150] hot969boston.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [144/150] en.wikipedia.org -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [145/150] mixgulfcoast.iheart.com -> vraiLabel=fake, original=fake, oppose=fake ,anonyme=fake, flip=non
# [146/150] scarlettjohansson.com.br -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [147/150] wanttoknow.info -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [148/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [149/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non
# [150/150] longroom.com -> vraiLabel=real, original=real, oppose=real ,anonyme=real, flip=non

# %% [markdown]
# **TEST**

# %% [markdown]
# **TEST****TEST**

# %% [markdown]
# **TEST**

# %% [markdown]
# **TEST**

# %% [markdown]
# **TEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEEESSSST**

# %%
def extraire_verdict2(reponse_llm):
    texte = reponse_llm.lower().strip()
    # Si la reponse est longue, c'est probablement un refus/une question, pas un verdict
    if len(texte.split()) > 5:
        return "indetermine"
    if re.search(r"\bfake\b", texte):
        return "fake"
    if re.search(r"\breal\b", texte):
        return "real"
    return "indetermine"


# On cherche l'article problematique dans le fichier D
chemin_in = "/kaggle/input/datasets/imenec/data-in/"
lignes_D = lire_csv(chemin_in + "categorie_D_egalise.csv")

id_a_tester = "gossipcop-913334"  # remplacez par l'id que vous voulez tester

article_test = None
for l in lignes_D:
    if l.get("id") == id_a_tester:
        article_test = l
        break

if article_test is None:
    print("Article non trouve, verifiez l'id.")
else:
    titre = article_test.get("title", "")
    texte = article_test.get("text", "")
    vraie_source = article_test.get("domaine", "source inconnue")

    print("Titre :", titre)
    print("Source :", vraie_source)
    print()

    # On construit le prompt SANS RAG (comme dans l'experience 2)
    prompt = construire_prompt(titre, texte, vraie_source)
    print("=== PROMPT ENVOYE ===")
    print(prompt)
    print()

    # On appelle Gemma directement, SANS passer par extraire_verdict,
    # pour voir la reponse brute telle quelle
    reponse = ollama.chat(model=m, messages=[
        {"role": "user", "content": prompt}
    ])
    contenu_brut = reponse["message"]["content"]

    print("=== REPONSE BRUTE DE GEMMA ===")
    print(contenu_brut)
    print()

    verdict_extrait = extraire_verdict2(contenu_brut)
    print("=== VERDICT EXTRAIT ===")
    print(verdict_extrait)
# Out:
# Titre :
# Source : k92radio.com
#
# === PROMPT ENVOYE ===
# Voici un article a verifier.
#
# Source : k92radio.com
# Titre :
# Texte :
#
# Preuves trouvees sur le web concernant cette affirmation :
#
# En te basant sur ce que tu connais, verifie si l'affirmation de cet article est vraie ou fausse.
# Reponds uniquement par un seul mot : "fake" ou "real".
#
# === REPONSE BRUTE DE GEMMA ===
# Veuillez me fournir le texte de l'article. Je ne peux pas vérifier l'affirmation sans le contenu de l'article.
#
#
# === VERDICT EXTRAIT ===
# indetermine

# %%
chemin_in = "/kaggle/input/datasets/imenec/data-in/"
chemin_out = "/kaggle/working/"

resultats_test_B = test_groupe(
    chemin_csv=chemin_in + "categorie_B_egalise.csv",
    nom_groupe="Catégorie B - Média connus et peu crédibles - TEST",
    chemin_sortie= chemin_out + "resultats_B_test_v2.csv",
    taille_groupe=150
)

# %%
chemin_in = "/kaggle/input/datasets/imenec/data-in/"
chemin_out = "/kaggle/working/"

resultats_test_D = test_groupe(
    chemin_csv=chemin_in + "categorie_D_egalise.csv",
    nom_groupe="Catégorie D - Média peu connus et peu crédibles - TEST",
    chemin_sortie= chemin_out + "resultats_D_test_v2.csv",
    taille_groupe=150
)

# %% [markdown]
# Résultat de l'experience 1 : pas de biais de notoriété sur l'accuracy globale. Mais il y a un vrai biais de méfiance différentielle : le LLM se montre plus sceptique envers les sources peu connues (il repère mieux leurs fake, mais rejette aussi plus de leurs vrais articles)
